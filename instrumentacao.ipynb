# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy import signal
import sympy as sp

# %%
yucs = np.array([0,100, 200, 500, 600, 700, 1000])
xucs = np.array([1.69, 1.76, 1.83, 2.04, 2.11, 2.18, 2.39])

y = np.array([0, 11, 65, 199, 220, 264, 318, 386, 1.17,  ])
x = np.array([1, 1.01, 1.03, 1.09, 1.10, 1.12, 1.14])

# %%
from numpy.polynomial import polynomial as P
c = np.polyfit(x,y,2)
print(f"{c[0]}*(x*x) + ({c[1]} * x) + {c[2]}")

xn = np.linspace(1.724,0.1,600)
yn = np.poly1d(c)
plt.plot( xn,yn(xn),x,y,'o')
# Out:
# -3.664815639393393e-12*(x*x) + (1428.571428571445 * x) + -2414.2857142857333
# ...

# %%
c = np.polyfit(x,y,1)
print(f"return {c[0]}*(x) + ({c[1]});")
# Out:
# return 1428.5714285714273*(x) + (-2414.285714285712);

# %%
x = 1.69
print(1428.5714285714273*(x) + (-2414.285714285712))
# Out:
# 0.0
